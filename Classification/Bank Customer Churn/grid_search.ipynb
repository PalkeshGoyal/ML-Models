# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
pd.options.mode.chained_assignment = None

# %%
bank_df = pd.read_csv("../../Data/Bank Customer Churn/Churn_Modelling.csv", header=0)
bank_df = bank_df.drop(['RowNumber','Surname',"CustomerId"],axis=1)
bank_df = bank_df.dropna()
obj_cols = ['Geography', 'Gender']
def grouped_mean(c_name):
    temp = bank_df.groupby(c_name)["Exited"].transform("mean")   
    return temp
for c_name in obj_cols:
    bank_df[c_name] = grouped_mean(c_name)
def treat_outlier(df):
    Q3 = np.quantile(df, 0.75)
    Q1 = np.quantile(df, 0.25)
    IQR = Q3 - Q1
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR
    df[df>upper_range] = upper_range
    df[df<lower_range] = lower_range
    return df
bank_df['Age'] = treat_outlier(bank_df['Age'])
bank_df['CreditScore'] = treat_outlier(bank_df['CreditScore'])

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X , y = bank_df.drop("Exited", axis=1) , bank_df['Exited']
X_train , X_test , y_train , y_test = train_test_split(X,y)

# %%
# rf_model = RandomForestClassifier(random_state=10,max_depth= 9, max_features= 5, n_estimators= 90)

# %%
# rf_params = [{
#     "n_estimators" : [90,100,110,120],
#     "max_depth" : [9],
#     "max_features" : [5]
# }]
# grid_model = GridSearchCV(rf_model , rf_params,cv=10,scoring="accuracy")
# grid_model.fit(X_train , y_train)

# %%
# print(grid_model.best_score_)
# print(grid_model.best_params_)
# best_dt_model = grid_model.best_estimator_

# %%
# predict = best_dt_model.predict(X_test)
# accuracy_score(y_true=y_test , y_pred=predict)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_model = GradientBoostingClassifier(random_state=10)
gb_model.fit(X_train,  y_train)
# Out:
# GradientBoostingClassifier(random_state=10)

# %%
predict = gb_model.predict(X_test)
print(accuracy_score(y_true=y_test , y_pred=predict))
print(accuracy_score(y_true=y_train , y_pred=gb_model.predict(X_train)))
# Out:
# 0.8588
# 0.8750333422245933

# %%
# from sklearn.linear_model import SGDClassifier

# %%
# sgd_mdoel = SGDClassifier(random_state = 10,early_stopping=True)
# sgd_mdoel.fit(X_train,y_train)

# %%
# print(accuracy_score(sgd_mdoel.predict(X_test),y_test))
# print(accuracy_score(sgd_mdoel.predict(X_train),y_train))

# %%
 
# from joblib import Parallel, delayed 
# import joblib

# %%
# joblib.dump(gb_model, 'gb_model.pkl')

# %%
# X_train.head()

# %%
# X_train.columns
